# %% [markdown]
# <a href="https://colab.research.google.com/github/bangreppo/Pemograman-Dasar-Konversi-Suhu-/blob/main/YOLOv5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div align="center">
#   <a href="https://ultralytics.com/yolo" target="_blank">
#     <img width="1024" src="https://raw.githubusercontent.com/ultralytics/assets/main/yolov5/v70/splash.png">
#   </a>
#
#   [中文](https://docs.ultralytics.com/zh/) | [한국어](https://docs.ultralytics.com/ko/) | [日本語](https://docs.ultralytics.com/ja/) | [Русский](https://docs.ultralytics.com/ru/) | [Deutsch](https://docs.ultralytics.com/de/) | [Français](https://docs.ultralytics.com/fr/) | [Español](https://docs.ultralytics.com/es/) | [Português](https://docs.ultralytics.com/pt/) | [Türkçe](https://docs.ultralytics.com/tr/) | [Tiếng Việt](https://docs.ultralytics.com/vi/) | [العربية](https://docs.ultralytics.com/ar/)
#
#   <a href="https://github.com/ultralytics/ultralytics/actions/workflows/ci.yml"><img src="https://github.com/ultralytics/ultralytics/actions/workflows/ci.yml/badge.svg" alt="Ultralytics CI"></a>
#   <a href="https://console.paperspace.com/github/ultralytics/ultralytics"><img src="https://assets.paperspace.io/img/gradient-badge.svg" alt="Run on Gradient"/></a>
#   <a href="https://colab.research.google.com/github/ultralytics/yolov5/blob/master/tutorial.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>
#   <a href="https://www.kaggle.com/models/ultralytics/yolo11"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open In Kaggle"></a>
#
#   <a href="https://ultralytics.com/discord"><img alt="Discord" src="https://img.shields.io/discord/1089800235347353640?logo=discord&logoColor=white&label=Discord&color=blue"></a>
#   <a href="https://community.ultralytics.com"><img alt="Ultralytics Forums" src="https://img.shields.io/discourse/users?server=https%3A%2F%2Fcommunity.ultralytics.com&logo=discourse&label=Forums&color=blue"></a>
#   <a href="https://reddit.com/r/ultralytics"><img alt="Ultralytics Reddit" src="https://img.shields.io/reddit/subreddit-subscribers/ultralytics?style=flat&logo=reddit&logoColor=white&label=Reddit&color=blue"></a>
# </div>
#
# This **Ultralytics YOLOv5 Colab Notebook** is the easiest way to get started with [YOLO models](https://www.ultralytics.com/yolo)—no installation needed. Built by [Ultralytics](https://www.ultralytics.com/), the creators of YOLO, this notebook walks you through running **state-of-the-art** models directly in your browser.
#
# Ultralytics models are constantly updated for performance and flexibility. They're **fast**, **accurate**, and **easy to use**, and they excel at [object detection](https://docs.ultralytics.com/tasks/detect/), [tracking](https://docs.ultralytics.com/modes/track/), [instance segmentation](https://docs.ultralytics.com/tasks/segment/), [image classification](https://docs.ultralytics.com/tasks/classify/), and [pose estimation](https://docs.ultralytics.com/tasks/pose/).
#
# Find detailed documentation in the [Ultralytics Docs](https://docs.ultralytics.com/). Get support via [GitHub Issues](https://github.com/ultralytics/ultralytics/issues/new/choose). Join discussions on [Discord](https://discord.com/invite/ultralytics), [Reddit](https://www.reddit.com/r/ultralytics/), and the [Ultralytics Community Forums](https://community.ultralytics.com/)!
#
# Request an Enterprise License for commercial use at [Ultralytics Licensing](https://www.ultralytics.com/license).
#
# <br>
# <div>
#   <a href="https://www.youtube.com/watch?v=ZN3nRZT7b24" target="_blank">
#     <img src="https://img.youtube.com/vi/ZN3nRZT7b24/maxresdefault.jpg" alt="Ultralytics Video" width="640" style="border-radius: 10px; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2);">
#   </a>
#
#   <p style="font-size: 16px; font-family: Arial, sans-serif; color: #555;">
#     <strong>Watch: </strong> How to Train
#     <a href="https://github.com/ultralytics/ultralytics">Ultralytics</a>
#     <a href="https://docs.ultralytics.com/models/yolo11/">YOLO11</a> Model on Custom Dataset using Google Colab Notebook 🚀
#   </p>
# </div>

# %% [markdown]
# # Setup
#
# Clone GitHub [repository](https://github.com/ultralytics/yolov5), install [dependencies](https://github.com/ultralytics/yolov5/blob/master/requirements.txt) and check PyTorch and GPU.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-416-gfe1d4d99 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.1/112.6 GB disk)

# %%
# !unzip -q ../train_data.zip -d ../

# %% [markdown]
# # 1. Detect
#
# `detect.py` runs YOLOv5 inference on a variety of sources, downloading models automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases), and saving results to `runs/detect`. Example inference sources are:
#
# ```shell
# python detect.py --source 0  # webcam
#                           img.jpg  # image
#                           vid.mp4  # video
#                           screen  # screenshot
#                           path/  # directory
#                          'path/*.jpg'  # glob
#                          'https://youtu.be/LNwODJXcvt4'  # YouTube
#                          'rtsp://example.com/media.mp4'  # RTSP, RTMP, HTTP stream
# ```

# %%
# !python detect.py --weights runs/train/exp3/weights/last.pt --img 640 --conf 0.90 --source ../video.mp4
# Out:
# detect: weights=['runs/train/exp3/weights/last.pt'], source=../video.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.9, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-416-gfe1d4d99 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/317) /content/video.mp4: 640x384 (no detections), 31.4ms
# video 1/1 (2/317) /content/video.mp4: 640x384 (no detections), 9.4ms
# video 1/1 (3/317) /content/video.mp4: 640x384 (no detections), 9.7ms
# video 1/1 (4/317) /content/video.mp4: 640x384 (no detections), 9.1ms
# video 1/1 (5/317) /content/video.mp4: 640x384 (no detections), 9.5ms
# video 1/1 (6/317) /content/video.mp4: 640x384 (no detections), 8.7ms
# video 1/1 (7/317) /content/video.mp4: 640x384 (no detections), 9.6ms
# video 1/1 (8/317) /content/video.mp4: 640x384 (no detections), 12.1ms
# video 1/1 (9/317) /content/video.mp4: 640x384 (no detections), 9.2ms
# video 1/1 (10/317) /content/video.mp4: 640x384 (no detections), 9.4ms
# video 1/1 (11/317) /content/video.mp4: 640x384 (no detections), 9.3ms
# video 1/1 (12/317) /content/video.mp4: 640x384 (no detections), 11.3ms
# video 1/1 (13/317) /content/video.mp4: 640x384 (no detections), 9.4ms
# video 1/1 (14/317) /content/video.mp4: 640x384 (no detections), 9.4ms
# video 1/1 (15/317) /content/video.mp4: 640x384 (no detections), 9.7ms
# video 1/1 (16/317) /content/video.mp4: 640x384 (no detections), 11.5ms
# video 1/1 (17/317) /content/video.mp4: 640x384 (no detections), 9.3ms
# video 1/1 (18/317) /content/video.mp4: 640x384 (no detections), 9.6ms
# video 1/1 (19/317) /content/video.mp4: 640x384 (no detections), 9.7ms
# video 1/1 (20/317) /content/video.mp4: 640x384 (no detections), 9.6ms
# video 1/1 (21/317) /content/video.mp4: 640x384 (no detections), 8.9ms
# video 1/1 (22/317) /content/video.mp4: 640x384 (no detections), 9.2ms
# video 1/1 (23/317) /content/video.mp4: 640x384 (no detections), 10.1ms
# video 1/1 (24/317) /content/video.mp4: 640x384 (no detections), 8.0ms
# video 1/1 (25/317) /content/video.mp4: 640x384 (no detections), 8.6ms
# video 1/1 (26/317) /content/video.mp4: 640x384 (no detections), 9.0ms
# video 1/1 (27/317) /content/video.mp4: 640x384 (no detections), 9.6ms
# video 1/1 (28/317) /content/video.mp4: 640x384 (no detections), 10.4ms
# video 1/1 (29/317) /content/video.mp4: 640x384 (no detections), 10.2ms
# video 1/1 (30/317) /content/video.mp4: 640x384 (no detections), 9.3ms
# video 1/1 (31/317) /content/video.mp4: 640x384 (no detections), 10.2ms
# video 1/1 (32/317) /content/video.mp4: 640x384 (no detections), 9.7ms
# video 1/1 (33/317) /content/video.mp4: 640x384 (no detections), 11.3ms
# video 1/1 (34/317) /content/video.mp4: 640x384 (no detections), 9.9ms
# video 1/1 (35/317) /content/video.mp4: 640x384 (no detections), 10.4ms
# video 1/1 (36/317) /content/video.mp4: 640x384 (no detections), 11.5ms
# video 1/1 (37/317) /content/video.mp4: 640x384 (no detections), 9.1ms
# video 1/1 (38/317) /content/video.mp4: 640x384 (no detections), 9.3ms
# video 1/1 (39/317) /content/video.mp4: 640x384 (no detections), 9.8ms
# video 1/1 (40/317) /content/video.mp4: 640x384 (no detections), 11.0ms
# video 1/1 (41/317) /content/video.mp4: 640x384 (no detections), 10.3ms
# video 1/1 (42/317) /content/video.mp4: 640x384 (no detections), 10.0ms
# video 1/1 (43/317) /content/video.mp4: 640x384 (no detections), 11.1ms
# video 1/1 (44/317) /content/video.mp4: 640x384 (no detections), 9.7ms
# video 1/1 (45/317) /content/video.mp4: 640x384 (no detections), 9.4ms
# video 1/1 (46/317) /content/video.mp4: 640x384 (no detections), 10.6ms
# video 1/1 (47/317) /content/video.mp4: 640x384 (no detections), 9.7ms
# video 1/1 (48/317) /content/video.mp4: 640x384 (no detections), 10.0ms
# video 1/1 (49/317) /content/video.mp4: 640x384 (no detections), 9.2ms
# video 1/1 (50/317) /content/video.mp4: 640x384 (no detections), 9.7ms
# video 1/1 (51/317) /content/video.mp4: 640x384 (no detections), 9.5ms
# video 1/1 (52/317) /content/video.mp4: 640x384 (no detections), 9.8ms
# video 1/1 (53/317) /content/video.mp4: 640x384 (no detections), 9.4ms
# video 1/1 (54/317) /content/video.mp4: 640x384 (no detections), 9.4ms
# video 1/1 (55/317) /content/video.mp4: 640x384 (no detections), 11.8ms
# video 1/1 (56/317) /content/video.mp4: 640x384 (no detections), 10.7ms
# video 1/1 (57/317) /content/video.mp4: 640x384 (no detections), 9.7ms
# video 1/1 (58/317) /content/video.mp4: 640x384 (no detections), 9.9ms
# video 1/1 (59/317) /content/video.mp4: 640x384 (no detections), 9.4ms
# video 1/1 (60/317) /content/video.mp4: 640x384 (no detections), 10.5ms
# video 1/1 (61/317) /content/video.mp4: 640x384 (no detections), 10.0ms
# video 1/1 (62/317) /content/video.mp4: 640x384 (no detections), 10.3ms
# video 1/1 (63/317) /content/video.mp4: 640x384 (no detections), 9.5ms
# video 1/1 (64/317) /content/video.mp4: 640x384 (no detections), 10.7ms
# video 1/1 (65/317) /content/video.mp4: 640x384 (no detections), 9.6ms
# video 1/1 (66/317) /content/video.mp4: 640x384 (no detections), 9.5ms
# video 1/1 (67/317) /content/video.mp4: 640x384 (no detections), 9.6ms
# video 1/1 (68/317) /content/video.mp4: 640x384 (no detections), 9.8ms
# video 1/1 (69/317) /content/video.mp4: 640x384 (no detections), 13.1ms
# video 1/1 (70/317) /content/video.mp4: 640x384 (no detections), 9.5ms
# video 1/1 (71/317) /content/video.mp4: 640x384 (no detections), 9.3ms
# video 1/1 (72/317) /content/video.mp4: 640x384 (no detections), 9.6ms
# video 1/1 (73/317) /content/video.mp4: 640x384 (no detections), 9.2ms
# video 1/1 (74/317) /content/video.mp4: 640x384 (no detections), 10.1ms
# video 1/1 (75/317) /content/video.mp4: 640x384 (no detections), 9.1ms
# video 1/1 (76/317) /content/video.mp4: 640x384 (no detections), 9.3ms
# video 1/1 (77/317) /content/video.mp4: 640x384 (no detections), 9.1ms
# video 1/1 (78/317) /content/video.mp4: 640x384 (no detections), 9.4ms
# video 1/1 (79/317) /content/video.mp4: 640x384 (no detections), 10.1ms
# video 1/1 (80/317) /content/video.mp4: 640x384 (no detections), 9.3ms
# video 1/1 (81/317) /content/video.mp4: 640x384 (no detections), 9.5ms
# video 1/1 (82/317) /content/video.mp4: 640x384 (no detections), 10.3ms
# video 1/1 (83/317) /content/video.mp4: 640x384 (no detections), 7.6ms
# video 1/1 (84/317) /content/video.mp4: 640x384 (no detections), 9.0ms
# video 1/1 (85/317) /content/video.mp4: 640x384 (no detections), 9.9ms
# video 1/1 (86/317) /content/video.mp4: 640x384 (no detections), 9.4ms
# video 1/1 (87/317) /content/video.mp4: 640x384 (no detections), 9.7ms
# video 1/1 (88/317) /content/video.mp4: 640x384 (no detections), 9.4ms
# video 1/1 (89/317) /content/video.mp4: 640x384 (no detections), 10.0ms
# video 1/1 (90/317) /content/video.mp4: 640x384 (no detections), 9.7ms
# video 1/1 (91/317) /content/video.mp4: 640x384 (no detections), 9.9ms
# video 1/1 (92/317) /content/video.mp4: 640x384 (no detections), 11.9ms
# video 1/1 (93/317) /content/video.mp4: 640x384 (no detections), 9.0ms
# video 1/1 (94/317) /content/video.mp4: 640x384 (no detections), 10.1ms
# video 1/1 (95/317) /content/video.mp4: 640x384 (no detections), 10.0ms
# video 1/1 (96/317) /content/video.mp4: 640x384 (no detections), 9.9ms
# video 1/1 (97/317) /content/video.mp4: 640x384 (no detections), 10.0ms
# video 1/1 (98/317) /content/video.mp4: 640x384 (no detections), 10.1ms
# video 1/1 (99/317) /content/video.mp4: 640x384 (no detections), 11.0ms
# video 1/1 (100/317) /content/video.mp4: 640x384 (no detections), 10.3ms
# video 1/1 (101/317) /content/video.mp4: 640x384 (no detections), 9.5ms
# video 1/1 (102/317) /content/video.mp4: 640x384 (no detections), 10.0ms
# video 1/1 (103/317) /content/video.mp4: 640x384 (no detections), 10.3ms
# video 1/1 (104/317) /content/video.mp4: 640x384 (no detections), 10.4ms
# video 1/1 (105/317) /content/video.mp4: 640x384 (no detections), 10.0ms
# video 1/1 (106/317) /content/video.mp4: 640x384 (no detections), 9.9ms
# video 1/1 (107/317) /content/video.mp4: 640x384 (no detections), 13.4ms
# video 1/1 (108/317) /content/video.mp4: 640x384 (no detections), 14.1ms
# video 1/1 (109/317) /content/video.mp4: 640x384 (no detections), 10.6ms
# video 1/1 (110/317) /content/video.mp4: 640x384 (no detections), 9.6ms
# video 1/1 (111/317) /content/video.mp4: 640x384 (no detections), 9.8ms
# video 1/1 (112/317) /content/video.mp4: 640x384 (no detections), 9.8ms
# video 1/1 (113/317) /content/video.mp4: 640x384 (no detections), 10.5ms
# video 1/1 (114/317) /content/video.mp4: 640x384 (no detections), 10.4ms
# video 1/1 (115/317) /content/video.mp4: 640x384 (no detections), 9.8ms
# video 1/1 (116/317) /content/video.mp4: 640x384 (no detections), 10.3ms
# video 1/1 (117/317) /content/video.mp4: 640x384 (no detections), 10.4ms
# video 1/1 (118/317) /content/video.mp4: 640x384 (no detections), 10.2ms
# video 1/1 (119/317) /content/video.mp4: 640x384 (no detections), 13.8ms
# video 1/1 (120/317) /content/video.mp4: 640x384 (no detections), 9.4ms
# video 1/1 (121/317) /content/video.mp4: 640x384 (no detections), 10.5ms
# video 1/1 (122/317) /content/video.mp4: 640x384 (no detections), 9.4ms
# video 1/1 (123/317) /content/video.mp4: 640x384 (no detections), 9.9ms
# video 1/1 (124/317) /content/video.mp4: 640x384 (no detections), 10.1ms
# video 1/1 (125/317) /content/video.mp4: 640x384 (no detections), 10.0ms
# video 1/1 (126/317) /content/video.mp4: 640x384 (no detections), 9.5ms
# video 1/1 (127/317) /content/video.mp4: 640x384 (no detections), 11.5ms
# video 1/1 (128/317) /content/video.mp4: 640x384 (no detections), 10.4ms
# video 1/1 (129/317) /content/video.mp4: 640x384 (no detections), 9.5ms
# video 1/1 (130/317) /content/video.mp4: 640x384 (no detections), 9.8ms
# video 1/1 (131/317) /content/video.mp4: 640x384 (no detections), 9.8ms
# video 1/1 (132/317) /content/video.mp4: 640x384 (no detections), 9.5ms
# video 1/1 (133/317) /content/video.mp4: 640x384 (no detections), 11.0ms
# video 1/1 (134/317) /content/video.mp4: 640x384 (no detections), 9.6ms
# video 1/1 (135/317) /content/video.mp4: 640x384 (no detections), 12.0ms
# video 1/1 (136/317) /content/video.mp4: 640x384 (no detections), 10.8ms
# video 1/1 (137/317) /content/video.mp4: 640x384 (no detections), 9.9ms
# video 1/1 (138/317) /content/video.mp4: 640x384 (no detections), 10.5ms
# video 1/1 (139/317) /content/video.mp4: 640x384 (no detections), 11.7ms
# video 1/1 (140/317) /content/video.mp4: 640x384 (no detections), 10.2ms
# video 1/1 (141/317) /content/video.mp4: 640x384 (no detections), 10.1ms
# video 1/1 (142/317) /content/video.mp4: 640x384 (no detections), 10.3ms
# video 1/1 (143/317) /content/video.mp4: 640x384 (no detections), 10.1ms
# video 1/1 (144/317) /content/video.mp4: 640x384 (no detections), 9.5ms
# video 1/1 (145/317) /content/video.mp4: 640x384 (no detections), 9.8ms
# video 1/1 (146/317) /content/video.mp4: 640x384 (no detections), 11.8ms
# video 1/1 (147/317) /content/video.mp4: 640x384 (no detections), 9.4ms
# video 1/1 (148/317) /content/video.mp4: 640x384 (no detections), 9.5ms
# video 1/1 (149/317) /content/video.mp4: 640x384 (no detections), 11.3ms
# video 1/1 (150/317) /content/video.mp4: 640x384 (no detections), 9.7ms
# video 1/1 (151/317) /content/video.mp4: 640x384 (no detections), 9.3ms
# video 1/1 (152/317) /content/video.mp4: 640x384 (no detections), 9.4ms
# video 1/1 (153/317) /content/video.mp4: 640x384 (no detections), 9.8ms
# video 1/1 (154/317) /content/video.mp4: 640x384 (no detections), 10.3ms
# video 1/1 (155/317) /content/video.mp4: 640x384 (no detections), 9.7ms
# video 1/1 (156/317) /content/video.mp4: 640x384 (no detections), 9.6ms
# video 1/1 (157/317) /content/video.mp4: 640x384 (no detections), 9.8ms
# video 1/1 (158/317) /content/video.mp4: 640x384 (no detections), 11.0ms
# video 1/1 (159/317) /content/video.mp4: 640x384 (no detections), 9.5ms
# video 1/1 (160/317) /content/video.mp4: 640x384 (no detections), 9.4ms
# video 1/1 (161/317) /content/video.mp4: 640x384 (no detections), 10.1ms
# video 1/1 (162/317) /content/video.mp4: 640x384 (no detections), 10.5ms
# video 1/1 (163/317) /content/video.mp4: 640x384 (no detections), 10.5ms
# video 1/1 (164/317) /content/video.mp4: 640x384 (no detections), 14.1ms
# video 1/1 (165/317) /content/video.mp4: 640x384 (no detections), 17.5ms
# video 1/1 (166/317) /content/video.mp4: 640x384 (no detections), 10.1ms
# video 1/1 (167/317) /content/video.mp4: 640x384 (no detections), 9.4ms
# video 1/1 (168/317) /content/video.mp4: 640x384 (no detections), 10.3ms
# video 1/1 (169/317) /content/video.mp4: 640x384 (no detections), 10.0ms
# video 1/1 (170/317) /content/video.mp4: 640x384 (no detections), 10.3ms
# video 1/1 (171/317) /content/video.mp4: 640x384 (no detections), 10.7ms
# video 1/1 (172/317) /content/video.mp4: 640x384 (no detections), 10.0ms
# video 1/1 (173/317) /content/video.mp4: 640x384 (no detections), 9.5ms
# video 1/1 (174/317) /content/video.mp4: 640x384 (no detections), 9.8ms
# video 1/1 (175/317) /content/video.mp4: 640x384 (no detections), 8.9ms
# video 1/1 (176/317) /content/video.mp4: 640x384 (no detections), 9.3ms
# video 1/1 (177/317) /content/video.mp4: 640x384 (no detections), 10.1ms
# video 1/1 (178/317) /content/video.mp4: 640x384 (no detections), 9.5ms
# video 1/1 (179/317) /content/video.mp4: 640x384 (no detections), 10.4ms
# video 1/1 (180/317) /content/video.mp4: 640x384 (no detections), 10.2ms
# video 1/1 (181/317) /content/video.mp4: 640x384 (no detections), 10.4ms
# video 1/1 (182/317) /content/video.mp4: 640x384 (no detections), 11.9ms
# video 1/1 (183/317) /content/video.mp4: 640x384 (no detections), 10.1ms
# video 1/1 (184/317) /content/video.mp4: 640x384 (no detections), 10.1ms
# video 1/1 (185/317) /content/video.mp4: 640x384 (no detections), 9.8ms
# video 1/1 (186/317) /content/video.mp4: 640x384 (no detections), 10.9ms
# video 1/1 (187/317) /content/video.mp4: 640x384 (no detections), 10.7ms
# video 1/1 (188/317) /content/video.mp4: 640x384 (no detections), 9.9ms
# video 1/1 (189/317) /content/video.mp4: 640x384 (no detections), 9.0ms
# video 1/1 (190/317) /content/video.mp4: 640x384 (no detections), 10.2ms
# video 1/1 (191/317) /content/video.mp4: 640x384 (no detections), 9.3ms
# video 1/1 (192/317) /content/video.mp4: 640x384 (no detections), 16.7ms
# video 1/1 (193/317) /content/video.mp4: 640x384 (no detections), 9.3ms
# video 1/1 (194/317) /content/video.mp4: 640x384 (no detections), 10.3ms
# video 1/1 (195/317) /content/video.mp4: 640x384 (no detections), 10.7ms
# video 1/1 (196/317) /content/video.mp4: 640x384 (no detections), 10.2ms
# video 1/1 (197/317) /content/video.mp4: 640x384 (no detections), 9.9ms
# video 1/1 (198/317) /content/video.mp4: 640x384 (no detections), 9.8ms
# video 1/1 (199/317) /content/video.mp4: 640x384 (no detections), 9.6ms
# video 1/1 (200/317) /content/video.mp4: 640x384 (no detections), 11.5ms
# video 1/1 (201/317) /content/video.mp4: 640x384 (no detections), 9.7ms
# video 1/1 (202/317) /content/video.mp4: 640x384 (no detections), 8.8ms
# video 1/1 (203/317) /content/video.mp4: 640x384 (no detections), 10.3ms
# video 1/1 (204/317) /content/video.mp4: 640x384 (no detections), 10.4ms
# video 1/1 (205/317) /content/video.mp4: 640x384 (no detections), 10.0ms
# video 1/1 (206/317) /content/video.mp4: 640x384 (no detections), 9.6ms
# video 1/1 (207/317) /content/video.mp4: 640x384 (no detections), 10.2ms
# video 1/1 (208/317) /content/video.mp4: 640x384 (no detections), 11.5ms
# video 1/1 (209/317) /content/video.mp4: 640x384 (no detections), 11.5ms
# video 1/1 (210/317) /content/video.mp4: 640x384 (no detections), 10.1ms
# video 1/1 (211/317) /content/video.mp4: 640x384 (no detections), 10.1ms
# video 1/1 (212/317) /content/video.mp4: 640x384 (no detections), 10.0ms
# video 1/1 (213/317) /content/video.mp4: 640x384 (no detections), 9.2ms
# video 1/1 (214/317) /content/video.mp4: 640x384 (no detections), 10.6ms
# video 1/1 (215/317) /content/video.mp4: 640x384 (no detections), 10.2ms
# video 1/1 (216/317) /content/video.mp4: 640x384 (no detections), 9.1ms
# video 1/1 (217/317) /content/video.mp4: 640x384 (no detections), 9.2ms
# video 1/1 (218/317) /content/video.mp4: 640x384 (no detections), 11.3ms
# video 1/1 (219/317) /content/video.mp4: 640x384 (no detections), 10.6ms
# video 1/1 (220/317) /content/video.mp4: 640x384 (no detections), 8.5ms
# video 1/1 (221/317) /content/video.mp4: 640x384 (no detections), 9.8ms
# video 1/1 (222/317) /content/video.mp4: 640x384 (no detections), 10.4ms
# video 1/1 (223/317) /content/video.mp4: 640x384 (no detections), 10.6ms
# video 1/1 (224/317) /content/video.mp4: 640x384 (no detections), 9.3ms
# video 1/1 (225/317) /content/video.mp4: 640x384 (no detections), 9.8ms
# video 1/1 (226/317) /content/video.mp4: 640x384 (no detections), 10.1ms
# video 1/1 (227/317) /content/video.mp4: 640x384 (no detections), 10.5ms
# video 1/1 (228/317) /content/video.mp4: 640x384 (no detections), 10.3ms
# video 1/1 (229/317) /content/video.mp4: 640x384 (no detections), 9.7ms
# video 1/1 (230/317) /content/video.mp4: 640x384 (no detections), 9.8ms
# video 1/1 (231/317) /content/video.mp4: 640x384 (no detections), 10.6ms
# video 1/1 (232/317) /content/video.mp4: 640x384 (no detections), 10.1ms
# video 1/1 (233/317) /content/video.mp4: 640x384 (no detections), 9.8ms
# video 1/1 (234/317) /content/video.mp4: 640x384 (no detections), 14.9ms
# video 1/1 (235/317) /content/video.mp4: 640x384 (no detections), 13.9ms
# video 1/1 (236/317) /content/video.mp4: 640x384 (no detections), 13.0ms
# video 1/1 (237/317) /content/video.mp4: 640x384 (no detections), 18.0ms
# video 1/1 (238/317) /content/video.mp4: 640x384 (no detections), 17.6ms
# video 1/1 (239/317) /content/video.mp4: 640x384 (no detections), 14.4ms
# video 1/1 (240/317) /content/video.mp4: 640x384 (no detections), 10.2ms
# video 1/1 (241/317) /content/video.mp4: 640x384 (no detections), 9.4ms
# video 1/1 (242/317) /content/video.mp4: 640x384 (no detections), 18.1ms
# video 1/1 (243/317) /content/video.mp4: 640x384 (no detections), 13.7ms
# video 1/1 (244/317) /content/video.mp4: 640x384 (no detections), 8.8ms
# video 1/1 (245/317) /content/video.mp4: 640x384 (no detections), 11.7ms
# video 1/1 (246/317) /content/video.mp4: 640x384 (no detections), 15.9ms
# video 1/1 (247/317) /content/video.mp4: 640x384 (no detections), 12.2ms
# video 1/1 (248/317) /content/video.mp4: 640x384 (no detections), 11.9ms
# video 1/1 (249/317) /content/video.mp4: 640x384 (no detections), 10.6ms
# video 1/1 (250/317) /content/video.mp4: 640x384 (no detections), 18.7ms
# video 1/1 (251/317) /content/video.mp4: 640x384 (no detections), 18.1ms
# video 1/1 (252/317) /content/video.mp4: 640x384 (no detections), 10.5ms
# video 1/1 (253/317) /content/video.mp4: 640x384 (no detections), 12.2ms
# video 1/1 (254/317) /content/video.mp4: 640x384 (no detections), 17.3ms
# video 1/1 (255/317) /content/video.mp4: 640x384 (no detections), 10.2ms
# video 1/1 (256/317) /content/video.mp4: 640x384 (no detections), 15.3ms
# video 1/1 (257/317) /content/video.mp4: 640x384 (no detections), 11.5ms
# video 1/1 (258/317) /content/video.mp4: 640x384 (no detections), 16.3ms
# video 1/1 (259/317) /content/video.mp4: 640x384 (no detections), 20.5ms
# video 1/1 (260/317) /content/video.mp4: 640x384 (no detections), 16.4ms
# video 1/1 (261/317) /content/video.mp4: 640x384 (no detections), 12.9ms
# video 1/1 (262/317) /content/video.mp4: 640x384 (no detections), 18.6ms
# video 1/1 (263/317) /content/video.mp4: 640x384 (no detections), 9.5ms
# video 1/1 (264/317) /content/video.mp4: 640x384 (no detections), 9.3ms
# video 1/1 (265/317) /content/video.mp4: 640x384 (no detections), 13.2ms
# video 1/1 (266/317) /content/video.mp4: 640x384 (no detections), 10.4ms
# video 1/1 (267/317) /content/video.mp4: 640x384 (no detections), 18.9ms
# video 1/1 (268/317) /content/video.mp4: 640x384 (no detections), 11.3ms
# video 1/1 (269/317) /content/video.mp4: 640x384 (no detections), 13.2ms
# video 1/1 (270/317) /content/video.mp4: 640x384 (no detections), 17.3ms
# video 1/1 (271/317) /content/video.mp4: 640x384 (no detections), 14.1ms
# video 1/1 (272/317) /content/video.mp4: 640x384 (no detections), 12.5ms
# video 1/1 (273/317) /content/video.mp4: 640x384 (no detections), 17.3ms
# video 1/1 (274/317) /content/video.mp4: 640x384 (no detections), 12.4ms
# video 1/1 (275/317) /content/video.mp4: 640x384 (no detections), 11.7ms
# video 1/1 (276/317) /content/video.mp4: 640x384 (no detections), 22.0ms
# video 1/1 (277/317) /content/video.mp4: 640x384 (no detections), 9.0ms
# video 1/1 (278/317) /content/video.mp4: 640x384 (no detections), 10.3ms
# video 1/1 (279/317) /content/video.mp4: 640x384 (no detections), 9.5ms
# video 1/1 (280/317) /content/video.mp4: 640x384 (no detections), 11.1ms
# video 1/1 (281/317) /content/video.mp4: 640x384 (no detections), 10.9ms
# video 1/1 (282/317) /content/video.mp4: 640x384 (no detections), 10.4ms
# video 1/1 (283/317) /content/video.mp4: 640x384 (no detections), 9.7ms
# video 1/1 (284/317) /content/video.mp4: 640x384 (no detections), 9.7ms
# video 1/1 (285/317) /content/video.mp4: 640x384 (no detections), 10.4ms
# video 1/1 (286/317) /content/video.mp4: 640x384 (no detections), 10.3ms
# video 1/1 (287/317) /content/video.mp4: 640x384 (no detections), 10.1ms
# video 1/1 (288/317) /content/video.mp4: 640x384 (no detections), 10.0ms
# video 1/1 (289/317) /content/video.mp4: 640x384 (no detections), 9.8ms
# video 1/1 (290/317) /content/video.mp4: 640x384 (no detections), 10.3ms
# video 1/1 (291/317) /content/video.mp4: 640x384 (no detections), 9.8ms
# video 1/1 (292/317) /content/video.mp4: 640x384 (no detections), 9.6ms
# video 1/1 (293/317) /content/video.mp4: 640x384 (no detections), 10.1ms
# video 1/1 (294/317) /content/video.mp4: 640x384 (no detections), 10.9ms
# video 1/1 (295/317) /content/video.mp4: 640x384 (no detections), 9.5ms
# video 1/1 (296/317) /content/video.mp4: 640x384 (no detections), 9.6ms
# video 1/1 (297/317) /content/video.mp4: 640x384 (no detections), 10.1ms
# video 1/1 (298/317) /content/video.mp4: 640x384 (no detections), 10.2ms
# video 1/1 (299/317) /content/video.mp4: 640x384 (no detections), 10.5ms
# video 1/1 (300/317) /content/video.mp4: 640x384 (no detections), 10.2ms
# video 1/1 (301/317) /content/video.mp4: 640x384 (no detections), 10.3ms
# video 1/1 (302/317) /content/video.mp4: 640x384 (no detections), 10.0ms
# video 1/1 (303/317) /content/video.mp4: 640x384 (no detections), 9.2ms
# video 1/1 (304/317) /content/video.mp4: 640x384 (no detections), 10.0ms
# video 1/1 (305/317) /content/video.mp4: 640x384 (no detections), 10.1ms
# video 1/1 (306/317) /content/video.mp4: 640x384 (no detections), 10.8ms
# video 1/1 (307/317) /content/video.mp4: 640x384 (no detections), 9.3ms
# video 1/1 (308/317) /content/video.mp4: 640x384 (no detections), 12.3ms
# video 1/1 (309/317) /content/video.mp4: 640x384 (no detections), 11.7ms
# video 1/1 (310/317) /content/video.mp4: 640x384 (no detections), 10.4ms
# video 1/1 (311/317) /content/video.mp4: 640x384 (no detections), 9.6ms
# video 1/1 (312/317) /content/video.mp4: 640x384 (no detections), 10.3ms
# video 1/1 (313/317) /content/video.mp4: 640x384 (no detections), 9.5ms
# video 1/1 (314/317) /content/video.mp4: 640x384 (no detections), 10.0ms
# video 1/1 (315/317) /content/video.mp4: 640x384 (no detections), 7.5ms
# video 1/1 (316/317) /content/video.mp4: 640x384 (no detections), 7.5ms
# video 1/1 (317/317) /content/video.mp4: 640x384 (no detections), 7.5ms
# Speed: 0.6ms pre-process, 10.7ms inference, 0.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp5

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img align="left" src="https://user-images.githubusercontent.com/26833433/127574988-6a558aa1-d268-44b9-bf6b-62d4c605cc72.jpg" width="600">

# %% [markdown]
# # 2. Validate
# Validate a model's accuracy on the [COCO](https://cocodataset.org/#home) dataset's `val` or `test` splits. Models are downloaded automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases). To show results by class use the `--verbose` flag.

# %%
# Download COCO val
torch.hub.download_url_to_file('https://github.com/ultralytics/assets/releases/download/v0.0.0/coco2017val.zip', 'tmp.zip')  # download (780M - 5000 images)
# !unzip -q tmp.zip -d ../datasets && rm tmp.zip  # unzip
# Out:
# 100%|██████████| 780M/780M [00:12<00:00, 66.6MB/s]

# %%
# Validate YOLOv5s on COCO val
# !python val.py --weights yolov5s.pt --data coco.yaml --img 640 --half
# Out:
# val: data=/content/yolov5/data/coco.yaml, weights=['yolov5s.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=True, project=runs/val, name=exp, exist_ok=False, half=True, dnn=False
# YOLOv5 🚀 v7.0-136-g71244ae Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# val: Scanning /content/datasets/coco/val2017... 4952 images, 48 backgrounds, 0 corrupt: 100% 5000/5000 [00:02<00:00, 2024.59it/s]
# val: New cache created: /content/datasets/coco/val2017.cache
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 157/157 [01:25<00:00,  1.84it/s]
#                    all       5000      36335      0.671      0.519      0.566      0.371
# Speed: 0.1ms pre-process, 3.1ms inference, 2.3ms NMS per image at shape (32, 3, 640, 640)
#
# Evaluating pycocotools mAP... saving runs/val/exp/yolov5s_predictions.json...
# loading annotations into memory...
# Done (t=0.43s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=5.32s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=78.89s).
# Accumulating evaluation results...
# DONE (t=14.51s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.374
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.572
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.402
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.211
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.423
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.489
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.311
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.516
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.566
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.378
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.625
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.722
# Results saved to runs/val/exp

# %% [markdown]
# # 3. Train
#
# <p align=""><a href="https://ultralytics.com/hub"><img width="1000" src="https://github.com/ultralytics/assets/raw/main/im/integrations-loop.png"/></a></p>
# Close the active learning loop by sampling images from your inference conditions with the `roboflow` pip package
# <br><br>
#
# Train a YOLOv5s model on the [COCO128](https://www.kaggle.com/datasets/ultralytics/coco128) dataset with `--data coco128.yaml`, starting from pretrained `--weights yolov5s.pt`, or from randomly initialized `--weights '' --cfg yolov5s.yaml`.
#
# - **Pretrained [Models](https://github.com/ultralytics/yolov5/tree/master/models)** are downloaded
# automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases)
# - **[Datasets](https://github.com/ultralytics/yolov5/tree/master/data)** available for autodownload include: [COCO](https://github.com/ultralytics/yolov5/blob/master/data/coco.yaml), [COCO128](https://github.com/ultralytics/yolov5/blob/master/data/coco128.yaml), [VOC](https://github.com/ultralytics/yolov5/blob/master/data/VOC.yaml), [Argoverse](https://github.com/ultralytics/yolov5/blob/master/data/Argoverse.yaml), [VisDrone](https://github.com/ultralytics/yolov5/blob/master/data/VisDrone.yaml), [GlobalWheat](https://github.com/ultralytics/yolov5/blob/master/data/GlobalWheat2020.yaml), [xView](https://github.com/ultralytics/yolov5/blob/master/data/xView.yaml), [Objects365](https://github.com/ultralytics/yolov5/blob/master/data/Objects365.yaml), [SKU-110K](https://github.com/ultralytics/yolov5/blob/master/data/SKU-110K.yaml).
# - **Training Results** are saved to `runs/train/` with incrementing run directories, i.e. `runs/train/exp2`, `runs/train/exp3` etc.
# <br>
#
# A **Mosaic Dataloader** is used for training which combines 4 images into 1 mosaic.

# %%
#@title Select YOLOv5 🚀 logger {run: 'auto'}
logger = 'Comet' #@param ['Comet', 'ClearML', 'TensorBoard']

if logger == 'Comet':
  # %pip install -q comet_ml
  import comet_ml; comet_ml.init()
elif logger == 'ClearML':
  # %pip install -q clearml
  import clearml; clearml.browser_login()
elif logger == 'TensorBoard':
  # %load_ext tensorboard
  # %tensorboard --logdir runs/train

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 16 --epochs 100 --data custom_data.yaml --weights yolov5s.pt --cache
# Out:
# 2025-04-22 13:27:06.966084: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745328426.987375   17176 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745328426.994281   17176 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# train: weights=yolov5s.pt, cfg=, data=custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-416-gfe1d4d99 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# COMET WARNING: Comet credentials have not been set. Comet will default to offline logging. Please set your credentials to enable online logging.
# COMET INFO: Using '/content/yolov5/.cometml-runs' path as offline directory. Pass 'offline_directory' parameter into constructor or set the 'COMET_OFFLINE_DIRECTORY' environment variable to manually choose where to store offline experiment archives.
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7022326 parameters, 7022326 gradients, 15.9 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# /content/yolov5/models/common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /content/yolov5/models/common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: 1 validation error for InitSchema
# size
#   Field required [type=missing, input_value={'scale': (0.8, 1.0), 'ra...'mask_interpolation': 0}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# train: Scanning /content/train_data/labels/train.cache... 229 images, 0 backgrounds, 0 corrupt: 100% 229/229 [00:00<?, ?it/s]
# train: Caching images (0.2GB ram): 100% 229/229 [00:00<00:00, 277.96it/s]
# val: Scanning /content/train_data/labels/val.cache... 229 images, 0 backgrounds, 0 corrupt: 100% 229/229 [00:00<?, ?it/s]
# val: Caching images (0.2GB ram): 100% 229/229 [00:01<00:00, 185.71it/s]
#
# AutoAnchor: 4.70 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp3/labels.jpg...
# /content/yolov5/train.py:355: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=amp)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp3
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/15 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/99      3.51G     0.1165    0.03568          0         45        640:   7% 1/15 [00:02<00:36,  2.60s/it]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/99      3.55G     0.1168    0.03563          0         44        640:  13% 2/15 [00:02<00:16,  1.26s/it]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/99      3.55G     0.1178     0.0349          0         41        640:  20% 3/15 [00:03<00:09,  1.22it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/99      3.55G     0.1192    0.03425          0         38        640:  27% 4/15 [00:03<00:07,  1.56it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/99      3.55G     0.1187    0.03384          0         38        640:  33% 5/15 [00:03<00:05,  1.84it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/99      3.55G     0.1183    0.03354          0         38        640:  40% 6/15 [00:04<00:04,  2.19it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/99      3.55G     0.1174    0.03345          0         39        640:  47% 7/15 [00:04<00:03,  2.47it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/99      3.55G     0.1163    0.03342          0         40        640:  53% 8/15 [00:04<00:02,  2.70it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/99      3.55G      0.115    0.03363          0         43        640:  60% 9/15 [00:05<00:02,  2.79it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/99      3.55G     0.1129    0.03361          0         36        640:  67% 10/15 [00:05<00:01,  2.77it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/99      3.55G     0.1117    0.03407          0         51        640:  73% 11/15 [00:05<00:01,  2.76it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/99      3.55G     0.1108    0.03412          0         45        640:  80% 12/15 [00:06<00:01,  2.92it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/99      3.55G     0.1097    0.03476          0         59        640:  87% 13/15 [00:06<00:00,  3.10it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/99      3.55G     0.1085    0.03445          0         33        640:  93% 14/15 [00:06<00:00,  3.04it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/99      3.55G     0.1073    0.03434          0         13        640: 100% 15/15 [00:07<00:00,  2.05it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 8/8 [00:04<00:00,  1.65it/s]
#                    all        229        310       0.19      0.458      0.173     0.0474
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/15 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/99         4G    0.08992    0.03423          0         45        640:   7% 1/15 [00:00<00:03,  4.25it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/99         4G    0.08961    0.03197          0         34        640:  13% 2/15 [00:00<00:03,  4.11it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/99         4G    0.08836    0.03226          0         41        640:  20% 3/15 [00:00<00:02,  4.38it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/99         4G    0.08849    0.03269          0         42        640:  27% 4/15 [00:00<00:02,  4.21it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/99         4G      0.088    0.03268          0         42        640:  33% 5/15 [00:01<00:02,  4.40it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/99         4G    0.08807     0.0333          0         53        640:  40% 6/15 [00:01<00:02,  4.00it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/99         4G     0.0875     0.0329          0         40        640:  47% 7/15 [00:01<00:01,  4.23it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/99         4G    0.08684    0.03273          0         43        640:  53% 8/15 [00:01<00:01,  4.20it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/99         4G    0.08612    0.03292          0         47        640:  60% 9/15 [00:02<00:01,  4.34it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/99         4G    0.08547    0.03314          0         49        640:  67% 10/15 [00:02<00:01,  4.26it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/99         4G    0.08503    0.03323          0         50        640:  73% 11/15 [00:02<00:00,  4.37it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/99         4G     0.0848    0.03281          0         39        640:  80% 12/15 [00:02<00:00,  4.31it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/99         4G    0.08401    0.03255          0         42        640:  87% 13/15 [00:03<00:00,  4.46it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/99         4G    0.08325    0.03224          0         38        640:  93% 14/15 [00:03<00:00,  4.37it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/99         4G    0.08186    0.03181          0         11        640: 100% 15/15 [00:03<00:00,  4.41it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 8/8 [00:03<00:00,  2.13it/s]
#                    all        229        310      0.421      0.577      0.389      0.137
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/15 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/99         4G     0.0743    0.03191          0         46        640:   7% 1/15 [00:00<00:03,  4.32it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/99         4G    0.07273    0.03018          0         41        640:  13% 2/15 [00:00<00:02,  4.41it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/99         4G    0.07328    0.03031          0         44        640:  20% 3/15 [00:00<00:02,  4.13it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/99         4G    0.07378    0.03065          0         48        640:  27% 4/15 [00:00<00:02,  4.37it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/99         4G    0.07308    0.03034          0         44        640:  33% 5/15 [00:01<00:02,  4.31it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/99         4G    0.07208    0.02935          0         40        640:  40% 6/15 [00:01<00:02,  4.33it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/99         4G    0.07174    0.02884          0         43        640:  47% 7/15 [00:01<00:01,  4.21it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/99         4G    0.07117    0.02866          0         44        640:  53% 8/15 [00:01<00:01,  4.39it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/99         4G    0.07142    0.02874          0         51        640:  60% 9/15 [00:02<00:01,  4.30it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/99         4G    0.07132    0.02858          0         44        640:  67% 10/15 [00:02<00:01,  4.36it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/99         4G    0.07138    0.02847          0         50        640:  73% 11/15 [00:02<00:00,  4.19it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/99         4G    0.07176    0.02801          0         37        640:  80% 12/15 [00:02<00:00,  4.37it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/99         4G    0.07163    0.02822          0         52        640:  87% 13/15 [00:03<00:00,  4.32it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/99         4G    0.07094    0.02741          0         29        640:  93% 14/15 [00:03<00:00,  4.45it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/99      4.01G    0.07045    0.02703          0         12        640: 100% 15/15 [00:03<00:00,  4.21it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 8/8 [00:02<00:00,  3.17it/s]
#                    all        229        310      0.649      0.597      0.576      0.233
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/15 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/99      4.01G    0.06849    0.02272          0         42        640:   7% 1/15 [00:00<00:02,  4.86it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/99      4.01G    0.06712     0.0251          0         51        640:  13% 2/15 [00:00<00:03,  4.28it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/99      4.01G    0.06938    0.02572          0         52        640:  20% 3/15 [00:00<00:02,  4.48it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/99      4.01G    0.07115    0.02436          0         38        640:  27% 4/15 [00:00<00:02,  4.27it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/99      4.01G    0.07038    0.02395          0         43        640:  33% 5/15 [00:01<00:02,  4.30it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/99      4.01G    0.06927    0.02372          0         42        640:  40% 6/15 [00:01<00:02,  4.08it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/99      4.01G    0.06951    0.02304          0         37        640:  47% 7/15 [00:01<00:01,  4.30it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/99      4.01G    0.06932     0.0227          0         41        640:  53% 8/15 [00:01<00:01,  4.41it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/99      4.01G    0.06953    0.02256          0         44        640:  60% 9/15 [00:02<00:01,  4.25it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/99      4.01G    0.06956    0.02268          0         50        640:  67% 10/15 [00:02<00:01,  4.41it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/99      4.01G    0.06966    0.02294          0         51        640:  73% 11/15 [00:02<00:00,  4.35it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/99      4.01G    0.06943    0.02299          0         48        640:  80% 12/15 [00:02<00:00,  4.14it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/99      4.01G    0.06936     0.0225          0         33        640:  87% 13/15 [00:03<00:00,  4.08it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/99      4.01G    0.06939     0.0228          0         54        640:  93% 14/15 [00:03<00:00,  3.91it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/99      4.01G     0.0695    0.02272          0         13        640: 100% 15/15 [00:03<00:00,  4.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 8/8 [00:03<00:00,  2.65it/s]
#                    all        229        310      0.804      0.797      0.783      0.293
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/15 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        4/99      4.01G    0.05936    0.02189          0         45        640:   7% 1/15 [00:00<00:02,  4.85it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        4/99      4.01G    0.06216     0.0207          0         37        640:  13% 2/15 [00:00<00:02,  4.79it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        4/99      4.01G     0.0631    0.02085          0         42        640:  20% 3/15 [00:00<00:02,  4.47it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        4/99      4.01G     0.0681    0.01907          0         31        640:  27% 4/15 [00:00<00:02,  4.59it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        4/99      4.01G    0.07011     0.0197          0         43        640:  33% 5/15 [00:01<00:02,  4.54it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        4/99      4.01G    0.07116    0.01957          0         41        640:  40% 6/15 [00:01<00:02,  4.21it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        4/99      4.01G    0.06967    0.01976          0         37        640:  47% 7/15 [00:01<00:01,  4.39it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        4/99      4.01G     0.0686    0.02052          0         49        640:  53% 8/15 [00:01<00:01,  4.42it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        4/99      4.01G    0.06759    0.02065          0         41        640:  60% 9/15 [00:02<00:01,  4.10it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        4/99      4.01G    0.06797    0.02095          0         49        640:  67% 10/15 [00:02<00:01,  4.32it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        4/99      4.01G    0.06795    0.02094          0         43        640:  73% 11/15 [00:02<00:00,  4.37it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        4/99      4.01G    0.06799    0.02099          0         41        640:  80% 12/15 [00:02<00:00,  4.31it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        4/99      4.01G    0.06755     0.0211          0         44        640:  87% 13/15 [00:02<00:00,  4.40it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        4/99      4.01G    0.06696    0.02105          0         42        640:  93% 14/15 [00:03<00:00,  4.44it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        4/99      4.03G    0.06471    0.02069          0         10        640: 100% 15/15 [00:03<00:00,  4.48it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 8/8 [00:02<00:00,  3.52it/s]
#                    all        229        310       0.48       0.59      0.504      0.205
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/15 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/99      4.03G    0.06885    0.02447          0         50        640:   7% 1/15 [00:00<00:03,  4.60it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/99      4.03G    0.06777    0.02113          0         39        640:  13% 2/15 [00:00<00:02,  4.61it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/99      4.03G    0.06858     0.0199          0         37        640:  20% 3/15 [00:00<00:02,  4.11it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/99      4.03G    0.06744    0.02006          0         41        640:  27% 4/15 [00:00<00:02,  4.35it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/99      4.03G    0.06764    0.01998          0         39        640:  33% 5/15 [00:01<00:02,  4.41it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/99      4.03G    0.06685    0.01957          0         38        640:  40% 6/15 [00:01<00:02,  4.14it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/99      4.03G    0.06831    0.01906          0         37        640:  47% 7/15 [00:01<00:01,  4.31it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/99      4.03G    0.06866    0.01913          0         47        640:  53% 8/15 [00:01<00:01,  4.44it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/99      4.03G    0.06872    0.01993          0         55        640:  60% 9/15 [00:02<00:01,  4.25it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/99      4.03G    0.06748    0.01964          0         36        640:  67% 10/15 [00:02<00:01,  4.34it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/99      4.03G    0.06676    0.01944          0         34        640:  73% 11/15 [00:02<00:01,  3.93it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/99      4.03G     0.0664    0.01987          0         50        640:  80% 12/15 [00:02<00:00,  3.89it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/99      4.03G    0.06597    0.01976          0         36        640:  87% 13/15 [00:03<00:00,  3.70it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/99      4.03G    0.06566    0.01985          0         42        640:  93% 14/15 [00:03<00:00,  3.58it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/99      4.03G    0.06548    0.02006          0         15        640: 100% 15/15 [00:03<00:00,  4.02it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 8/8 [00:02<00:00,  3.05it/s]
#                    all        229        310      0.409      0.474      0.328     0.0871
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/15 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/99      4.03G    0.06566    0.02078          0         48        640:   7% 1/15 [00:00<00:02,  4.84it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/99      4.03G    0.06441    0.01926          0         37        640:  13% 2/15 [00:00<00:03,  4.32it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/99      4.03G    0.06167    0.01965          0         39        640:  20% 3/15 [00:00<00:02,  4.52it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/99      4.03G    0.06065    0.01886          0         36        640:  27% 4/15 [00:00<00:02,  4.52it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/99      4.03G    0.05967     0.0184          0         35        640:  33% 5/15 [00:01<00:02,  4.40it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/99      4.03G    0.06039    0.01832          0         37        640:  40% 6/15 [00:01<00:02,  4.24it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/99      4.03G    0.06126    0.01884          0         50        640:  47% 7/15 [00:01<00:01,  4.37it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/99      4.03G    0.06221    0.01933          0         51        640:  53% 8/15 [00:01<00:01,  4.29it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/99      4.03G    0.06296    0.01904          0         39        640:  60% 9/15 [00:02<00:01,  4.38it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/99      4.03G    0.06293    0.01893          0         39        640:  67% 10/15 [00:02<00:01,  4.22it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/99      4.03G    0.06232    0.01868          0         36        640:  73% 11/15 [00:02<00:00,  4.34it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/99      4.03G    0.06228    0.01901          0         48        640:  80% 12/15 [00:02<00:00,  4.33it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/99      4.03G    0.06195    0.01909          0         43        640:  87% 13/15 [00:02<00:00,  4.31it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/99      4.03G    0.06137    0.01908          0         40        640:  93% 14/15 [00:03<00:00,  4.21it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/99      4.04G    0.06194    0.01897          0         11        640: 100% 15/15 [00:03<00:00,  4.46it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 8/8 [00:02<00:00,  3.61it/s]
#                    all        229        310      0.351      0.874      0.455      0.144
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/15 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/99      4.04G    0.06496    0.01728          0         36        640:   7% 1/15 [00:00<00:03,  4.64it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/99      4.04G    0.06332      0.021          0         53        640:  13% 2/15 [00:00<00:02,  4.48it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/99      4.04G    0.06369    0.02176          0         49        640:  20% 3/15 [00:00<00:02,  4.32it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/99      4.04G    0.06242    0.02076          0         39        640:  27% 4/15 [00:00<00:02,  4.23it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/99      4.04G    0.06155    0.02148          0         53        640:  33% 5/15 [00:01<00:02,  4.00it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/99      4.04G    0.06065    0.02164          0         46        640:  40% 6/15 [00:01<00:02,  4.09it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/99      4.04G    0.06025    0.02045          0         31        640:  47% 7/15 [00:01<00:01,  4.01it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/99      4.04G    0.05989    0.01964          0         34        640:  53% 8/15 [00:01<00:01,  4.23it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/99      4.04G    0.05954    0.01955          0         41        640:  60% 9/15 [00:02<00:01,  4.07it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/99      4.04G    0.05942     0.0198          0         49        640:  67% 10/15 [00:02<00:01,  4.23it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/99      4.04G    0.05887    0.01963          0         41        640:  73% 11/15 [00:02<00:00,  4.10it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/99      4.04G    0.05935    0.01942          0         42        640:  80% 12/15 [00:02<00:00,  4.15it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/99      4.04G    0.05972    0.01934          0         45        640:  87% 13/15 [00:03<00:00,  3.76it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/99      4.04G    0.06023    0.01901          0         37        640:  93% 14/15 [00:03<00:00,  3.62it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/99      4.05G    0.06076    0.01897          0         14        640: 100% 15/15 [00:03<00:00,  3.99it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 8/8 [00:02<00:00,  2.88it/s]
#                    all        229        310      0.743      0.707      0.816      0.274
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/15 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/99      4.05G     0.0521    0.02105          0         51        640:   7% 1/15 [00:00<00:02,  4.86it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/99      4.05G    0.05337    0.02106          0         48        640:  13% 2/15 [00:00<00:02,  4.64it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/99      4.05G    0.05402    0.02035          0         40        640:  20% 3/15 [00:00<00:02,  4.46it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/99      4.05G    0.05498    0.01921          0         35        640:  27% 4/15 [00:00<00:02,  4.24it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/99      4.05G    0.05715    0.01937          0         45        640:  33% 5/15 [00:01<00:02,  4.43it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...
#       98/99      4.16G    0.02804    0.01209          0         44        640:  27% 4/15 [00:00<00:02,  4.02it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       98/99      4.16G    0.02829    0.01226          0         46        640:  33% 5/15 [00:01<00:02,  3.85it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       98/99      4.16G    0.02874    0.01231          0         41        640:  40% 6/15 [00:01<00:02,  3.90it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       98/99      4.16G    0.02816    0.01228          0         43        640:  47% 7/15 [00:01<00:02,  3.91it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       98/99      4.16G    0.02838    0.01252          0         44        640:  53% 8/15 [00:01<00:01,  4.13it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       98/99      4.16G    0.02831     0.0124          0         40        640:  60% 9/15 [00:02<00:01,  4.06it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       98/99      4.16G    0.02846    0.01249          0         42        640:  67% 10/15 [00:02<00:01,  4.00it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       98/99      4.16G    0.02823    0.01257          0         51        640:  73% 11/15 [00:02<00:00,  4.23it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       98/99      4.16G     0.0281    0.01257          0         42        640:  80% 12/15 [00:02<00:00,  4.15it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       98/99      4.16G     0.0279    0.01245          0         37        640:  87% 13/15 [00:03<00:00,  4.30it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       98/99      4.16G    0.02778    0.01243          0         40        640:  93% 14/15 [00:03<00:00,  4.10it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       98/99      4.16G    0.02769    0.01261          0         14        640: 100% 15/15 [00:03<00:00,  4.20it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 8/8 [00:02<00:00,  3.44it/s]
#                    all        229        310      0.974      0.981      0.989      0.663
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/15 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       99/99      4.16G    0.02886    0.01459          0         51        640:   7% 1/15 [00:00<00:02,  4.90it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       99/99      4.16G    0.02873    0.01388          0         44        640:  13% 2/15 [00:00<00:02,  4.60it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       99/99      4.16G     0.0279    0.01319          0         40        640:  20% 3/15 [00:00<00:02,  4.28it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       99/99      4.16G    0.02783    0.01308          0         44        640:  27% 4/15 [00:00<00:02,  4.02it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       99/99      4.16G    0.02781    0.01312          0         46        640:  33% 5/15 [00:01<00:02,  4.26it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       99/99      4.16G    0.02759    0.01282          0         34        640:  40% 6/15 [00:01<00:02,  4.18it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       99/99      4.16G    0.02703    0.01263          0         43        640:  47% 7/15 [00:01<00:02,  3.99it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       99/99      4.16G    0.02694    0.01256          0         41        640:  53% 8/15 [00:01<00:01,  4.16it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       99/99      4.16G    0.02715    0.01224          0         33        640:  60% 9/15 [00:02<00:01,  4.09it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       99/99      4.16G    0.02736    0.01243          0         47        640:  67% 10/15 [00:02<00:01,  3.96it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       99/99      4.16G    0.02768    0.01248          0         45        640:  73% 11/15 [00:02<00:01,  3.39it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       99/99      4.16G    0.02752    0.01237          0         39        640:  80% 12/15 [00:03<00:00,  3.55it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       99/99      4.16G    0.02768    0.01218          0         30        640:  87% 13/15 [00:03<00:00,  3.56it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       99/99      4.16G    0.02737    0.01203          0         36        640:  93% 14/15 [00:03<00:00,  3.32it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       99/99      4.16G    0.02711    0.01256          0         19        640: 100% 15/15 [00:04<00:00,  3.70it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 8/8 [00:02<00:00,  2.93it/s]
#                    all        229        310      0.976      0.981      0.989      0.663
#
# 100 epochs completed in 0.186 hours.
# Optimizer stripped from runs/train/exp3/weights/last.pt, 14.4MB
# Optimizer stripped from runs/train/exp3/weights/best.pt, 14.4MB
#
# Validating runs/train/exp3/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 8/8 [00:03<00:00,  2.23it/s]
#                    all        229        310       0.98      0.987      0.991      0.666
# Results saved to runs/train/exp3
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml OfflineExperiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : exp
# COMET INFO:     url                   : [OfflineExperiment will get URL after upload]
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     loss [110]                 : (0.5585112571716309, 2.434238910675049)
# COMET INFO:     metrics/mAP_0.5 [200]      : (0.17342396804563903, 0.9936428637191203)
# COMET INFO:     metrics/mAP_0.5:0.95 [200] : (0.04744219733579866, 0.6663712284404399)
# COMET INFO:     metrics/precision [200]    : (0.18999627665664362, 0.9895519337763594)
# COMET INFO:     metrics/recall [200]       : (0.45806451612903226, 0.9903225806451613)
# COMET INFO:     train/box_loss [200]       : (0.02711072936654091, 0.10727620869874954)
# COMET INFO:     train/cls_loss             : 0.0
# COMET INFO:     train/obj_loss [200]       : (0.011367985978722572, 0.034337904304265976)
# COMET INFO:     val/box_loss [200]         : (0.02551957219839096, 0.08146370947360992)
# COMET INFO:     val/cls_loss               : 0.0
# COMET INFO:     val/obj_loss [200]         : (0.0072654783725738525, 0.025125503540039062)
# COMET INFO:     x/lr0 [200]                : (0.0002980000000000002, 0.0874)
# COMET INFO:     x/lr1 [200]                : (0.0002980000000000002, 0.009406)
# COMET INFO:     x/lr2 [200]                : (0.0002980000000000002, 0.009406)
# COMET INFO:   Others:
# COMET INFO:     Name                        : exp
# COMET INFO:     comet_log_batch_metrics     : False
# COMET INFO:     comet_log_confusion_matrix  : True
# COMET INFO:     comet_log_per_class_metrics : False
# COMET INFO:     comet_max_image_uploads     : 100
# COMET INFO:     comet_mode                  : online
# COMET INFO:     comet_model_name            : yolov5
# COMET INFO:     hasNestedParams             : True
# COMET INFO:     offline_experiment          : True
# COMET INFO:   Parameters:
# COMET INFO:     anchor_t            : 4.0
# COMET INFO:     artifact_alias      : latest
# COMET INFO:     batch_size          : 16
# COMET INFO:     bbox_interval       : -1
# COMET INFO:     box                 : 0.05
# COMET INFO:     bucket              :
# COMET INFO:     cfg                 :
# COMET INFO:     cls                 : 0.006250000000000001
# COMET INFO:     cls_pw              : 1.0
# COMET INFO:     copy_paste          : 0.0
# COMET INFO:     cos_lr              : False
# COMET INFO:     degrees             : 0.0
# COMET INFO:     device              :
# COMET INFO:     entity              : None
# COMET INFO:     evolve              : None
# COMET INFO:     evolve_population   : data/hyps
# COMET INFO:     exist_ok            : False
# COMET INFO:     fl_gamma            : 0.0
# COMET INFO:     fliplr              : 0.5
# COMET INFO:     flipud              : 0.0
# COMET INFO:     freeze              : [0]
# COMET INFO:     hsv_h               : 0.015
# COMET INFO:     hsv_s               : 0.7
# COMET INFO:     hsv_v               : 0.4
# COMET INFO:     hyp|anchor_t        : 4.0
# COMET INFO:     hyp|box             : 0.05
# COMET INFO:     hyp|cls             : 0.5
# COMET INFO:     hyp|cls_pw          : 1.0
# COMET INFO:     hyp|copy_paste      : 0.0
# COMET INFO:     hyp|degrees         : 0.0
# COMET INFO:     hyp|fl_gamma        : 0.0
# COMET INFO:     hyp|fliplr          : 0.5
# COMET INFO:     hyp|flipud          : 0.0
# COMET INFO:     hyp|hsv_h           : 0.015
# COMET INFO:     hyp|hsv_s           : 0.7
# COMET INFO:     hyp|hsv_v           : 0.4
# COMET INFO:     hyp|iou_t           : 0.2
# COMET INFO:     hyp|lr0             : 0.01
# COMET INFO:     hyp|lrf             : 0.01
# COMET INFO:     hyp|mixup           : 0.0
# COMET INFO:     hyp|momentum        : 0.937
# COMET INFO:     hyp|mosaic          : 1.0
# COMET INFO:     hyp|obj             : 1.0
# COMET INFO:     hyp|obj_pw          : 1.0
# COMET INFO:     hyp|perspective     : 0.0
# COMET INFO:     hyp|scale           : 0.5
# COMET INFO:     hyp|shear           : 0.0
# COMET INFO:     hyp|translate       : 0.1
# COMET INFO:     hyp|warmup_bias_lr  : 0.1
# COMET INFO:     hyp|warmup_epochs   : 3.0
# COMET INFO:     hyp|warmup_momentum : 0.8
# COMET INFO:     hyp|weight_decay    : 0.0005
# COMET INFO:     image_weights       : False
# COMET INFO:     imgsz               : 640
# COMET INFO:     iou_t               : 0.2
# COMET INFO:     label_smoothing     : 0.0
# COMET INFO:     local_rank          : -1
# COMET INFO:     lr0                 : 0.01
# COMET INFO:     lrf                 : 0.01
# COMET INFO:     mixup               : 0.0
# COMET INFO:     momentum            : 0.937
# COMET INFO:     mosaic              : 1.0
# COMET INFO:     multi_scale         : False
# COMET INFO:     name                : exp
# COMET INFO:     ndjson_console      : False
# COMET INFO:     ndjson_file         : False
# COMET INFO:     noautoanchor        : False
# COMET INFO:     noplots             : False
# COMET INFO:     nosave              : False
# COMET INFO:     noval               : False
# COMET INFO:     obj                 : 1.0
# COMET INFO:     obj_pw              : 1.0
# COMET INFO:     optimizer           : SGD
# COMET INFO:     patience            : 100
# COMET INFO:     perspective         : 0.0
# COMET INFO:     project             : runs/train
# COMET INFO:     quad                : False
# COMET INFO:     rect                : False
# COMET INFO:     resume              : False
# COMET INFO:     resume_evolve       : None
# COMET INFO:     save_dir            : runs/train/exp3
# COMET INFO:     save_period         : -1
# COMET INFO:     scale               : 0.5
# COMET INFO:     seed                : 0
# COMET INFO:     shear               : 0.0
# COMET INFO:     single_cls          : False
# COMET INFO:     sync_bn             : False
# COMET INFO:     translate           : 0.1
# COMET INFO:     upload_dataset      : False
# COMET INFO:     val_conf_threshold  : 0.001
# COMET INFO:     val_iou_threshold   : 0.6
# COMET INFO:     warmup_bias_lr      : 0.1
# COMET INFO:     warmup_epochs       : 3.0
# COMET INFO:     warmup_momentum     : 0.8
# COMET INFO:     weight_decay        : 0.0005
# COMET INFO:     workers             : 8
# COMET INFO:   Uploads:
# COMET INFO:     asset               : 13 (996.41 KB)
# COMET INFO:     confusion-matrix    : 1
# COMET INFO:     environment details : 1
# COMET INFO:     git metadata        : 1
# COMET INFO:     images              : 6
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     os packages         : 1
# COMET INFO:
# COMET INFO: Still saving offline stats to messages file before program termination (may take up to 120 seconds)
# COMET INFO: Begin archiving the offline data.
# COMET INFO: To upload this offline experiment, run:
#     comet upload /content/yolov5/.cometml-runs/ad52574c983a47f68565eef433d0d018.zip

# %% [markdown]
# # 4. Visualize

# %% [markdown]
# ## Comet Logging and Visualization 🌟 NEW
#
# [Comet](https://www.comet.com/site/lp/yolov5-with-comet/?utm_source=yolov5&utm_medium=partner&utm_campaign=partner_yolov5_2022&utm_content=yolov5_colab) is now fully integrated with YOLOv5. Track and visualize model metrics in real time, save your hyperparameters, datasets, and model checkpoints, and visualize your model predictions with [Comet Custom Panels](https://www.comet.com/docs/v2/guides/comet-dashboard/code-panels/about-panels/?utm_source=yolov5&utm_medium=partner&utm_campaign=partner_yolov5_2022&utm_content=yolov5_colab)! Comet makes sure you never lose track of your work and makes it easy to share results and collaborate across teams of all sizes!
#
# Getting started is easy:
# ```shell
# pip install comet_ml  # 1. install
# export COMET_API_KEY=<Your API Key>  # 2. paste API key
# python train.py --img 640 --epochs 3 --data coco128.yaml --weights yolov5s.pt  # 3. train
# ```
# To learn more about all of the supported Comet features for this integration, check out the [Comet Tutorial](https://docs.ultralytics.com/yolov5/tutorials/comet_logging_integration). If you'd like to learn more about Comet, head over to our [documentation](https://www.comet.com/docs/v2/?utm_source=yolov5&utm_medium=partner&utm_campaign=partner_yolov5_2022&utm_content=yolov5_colab). Get started by trying out the Comet Colab Notebook:
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1RG0WOQyxlDlo5Km8GogJpIEJlg_5lyYO?usp=sharing)
#
# <a href="https://bit.ly/yolov5-readme-comet2">
# <img alt="Comet Dashboard" src="https://user-images.githubusercontent.com/26833433/202851203-164e94e1-2238-46dd-91f8-de020e9d6b41.png" width="1280"/></a>

# %% [markdown]
# ## ClearML Logging and Automation 🌟 NEW
#
# [ClearML](https://cutt.ly/yolov5-notebook-clearml) is completely integrated into YOLOv5 to track your experimentation, manage dataset versions and even remotely execute training runs. To enable ClearML (check cells above):
#
# - `pip install clearml`
# - run `clearml-init` to connect to a ClearML server (**deploy your own [open-source server](https://github.com/allegroai/clearml-server)**, or use our [free hosted server](https://cutt.ly/yolov5-notebook-clearml))
#
# You'll get all the great expected features from an experiment manager: live updates, model upload, experiment comparison etc. but ClearML also tracks uncommitted changes and installed packages for example. Thanks to that ClearML Tasks (which is what we call experiments) are also reproducible on different machines! With only 1 extra line, we can schedule a YOLOv5 training task on a queue to be executed by any number of ClearML Agents (workers).
#
# You can use ClearML Data to version your dataset and then pass it to YOLOv5 simply using its unique ID. This will help you keep track of your data without adding extra hassle. Explore the [ClearML Tutorial](https://docs.ultralytics.com/yolov5/tutorials/clearml_logging_integration) for details!
#
# <a href="https://cutt.ly/yolov5-notebook-clearml">
# <img alt="ClearML Experiment Management UI" src="https://github.com/thepycoder/clearml_screenshots/raw/main/scalars.jpg" width="1280"/></a>

# %% [markdown]
# ## Local Logging
#
# Training results are automatically logged with [Tensorboard](https://www.tensorflow.org/tensorboard) and [CSV](https://github.com/ultralytics/yolov5/pull/4148) loggers to `runs/train`, with a new experiment directory created for each new training as `runs/train/exp2`, `runs/train/exp3`, etc.
#
# This directory contains train and val statistics, mosaics, labels, predictions and augmentated mosaics, as well as metrics and charts including precision-recall (PR) curves and confusion matrices.
#
# <img alt="Local logging results" src="https://user-images.githubusercontent.com/26833433/183222430-e1abd1b7-782c-4cde-b04d-ad52926bf818.jpg" width="1280"/>

# %% [markdown]
# # Environments
#
# YOLOv5 may be run in any of the following up-to-date verified environments (with all dependencies including [CUDA](https://developer.nvidia.com/cuda)/[CUDNN](https://developer.nvidia.com/cudnn), [Python](https://www.python.org/) and [PyTorch](https://pytorch.org/) preinstalled):
#
# - **Notebooks** with free GPU: <a href="https://bit.ly/yolov5-paperspace-notebook"><img src="https://assets.paperspace.io/img/gradient-badge.svg" alt="Run on Gradient"></a> <a href="https://colab.research.google.com/github/ultralytics/yolov5/blob/master/tutorial.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a> <a href="https://www.kaggle.com/models/ultralytics/yolov5"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open In Kaggle"></a>
# - **Google Cloud** Deep Learning VM. See [GCP Quickstart Guide](https://docs.ultralytics.com/yolov5/environments/google_cloud_quickstart_tutorial/)
# - **Amazon** Deep Learning AMI. See [AWS Quickstart Guide](https://docs.ultralytics.com/yolov5/environments/aws_quickstart_tutorial/)
# - **Docker Image**. See [Docker Quickstart Guide](https://docs.ultralytics.com/yolov5/environments/docker_image_quickstart_tutorial/) <a href="https://hub.docker.com/r/ultralytics/yolov5"><img src="https://img.shields.io/docker/pulls/ultralytics/yolov5?logo=docker" alt="Docker Pulls"></a>

# %% [markdown]
# # Status
#
# ![YOLOv5 CI](https://github.com/ultralytics/yolov5/actions/workflows/ci-testing.yml/badge.svg)
#
# If this badge is green, all [YOLOv5 GitHub Actions](https://github.com/ultralytics/yolov5/actions) Continuous Integration (CI) tests are currently passing. CI tests verify correct operation of YOLOv5 training ([train.py](https://github.com/ultralytics/yolov5/blob/master/train.py)), testing ([val.py](https://github.com/ultralytics/yolov5/blob/master/val.py)), inference ([detect.py](https://github.com/ultralytics/yolov5/blob/master/detect.py)) and export ([export.py](https://github.com/ultralytics/yolov5/blob/master/export.py)) on macOS, Windows, and Ubuntu every 24 hours and on every commit.

# %% [markdown]
# # Appendix
#
# Additional content below.

# %%
# YOLOv5 PyTorch HUB Inference (DetectionModels only)
import torch

model = torch.hub.load('ultralytics/yolov5', 'yolov5s', force_reload=True, trust_repo=True)  # or yolov5n - yolov5x6 or custom
im = 'https://ultralytics.com/images/zidane.jpg'  # file, Path, PIL.Image, OpenCV, nparray, list
results = model(im)  # inference
results.print()  # or .show(), .save(), .crop(), .pandas(), etc.
